# %% [markdown]
# # ArcGIS API for Python: AIS Route Extraction Prototype
#
# ## A collaboration between the U.S. Department of Transportation and Esri
#
# ###### Alberto Nieto (Esri), Andrew Barrows (USDOT), Dominic Menegus (USDOT)
#
# This Jupyter Notebook contains documentation, processing, and data visualization of a prototype process in which the Automated Identification System (AIS) vessel data for specified terminal-to-terminal connections is used to digitize a route polyline dataset for an authoritative GIS.
#
# This process can be leveraged to develop an Information Product that generates data-driven ferry routes for all terminals in the United States, and could be extended to other environments and use cases.
#
# Contact Info:
# anieto@esri.com

# %% [markdown]
# # Ask Questions

# %% [markdown]
# ### How can we determine "average" paths for ferry routes in the United States?

# %% [markdown]
# # Proposed Methodology

# %% [markdown]
# #### Use AIS positional data to determine ship positions along routes, perform qualitative checks, and digitize polyline geometry

# %% [markdown]
# <img src="../../docs/dbclustering.PNG"></img>

# %% [markdown]
# #### Script Set-up (Imports, variables, etc.) (Pre-process)

# %%
import arcgis
import plotly
import statsmodels.api as sm
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
# %matplotlib inline  

gis = arcgis.gis.GIS()

# %%
gis_app_id = r"wt3QUR1M4eum0TVI"
gis_url = r"https://esrifederal.maps.arcgis.com"
gis = arcgis.gis.GIS(gis_url, client_id=gis_app_id)
# Out:
# Please sign in to your GIS and paste the code that is obtained below.
# If a web browser does not automatically open, please navigate to the URL below yourself instead.
# Opening web browser to navigate to: https://esrifederal.maps.arcgis.com/sharing/rest/oauth2/authorize?client_id=wt3QUR1M4eum0TVI&response_type=code&expiration=-1&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob
# Enter code obtained on signing in using SAML: ········

# %% [markdown]
# # Part 1: Retrieve and Explore AIS Data

# %% [markdown]
# #### Code to Retrieve AIS Data

# %%
ais_sample = gis.content.search("AIS_StatenIsland_Sample", item_type="feature layer")[0]
ais_sample

# %% [markdown]
# #### Map of AIS Data

# %%
nyc_map = gis.map("New York City")
nyc_map.add_layer(ais_sample)
nyc_map.basemap = 'streets-night-vector'
nyc_map

# %% [markdown]
# <img src="img/capture05.png">

# %% [markdown]
# # Part 2: Run Lowess

# %% [markdown]
# ### Explanation of Loess/Lowess

# %% [markdown]
# Locally Weighted Scatterplot (LOWESS) Basic Facts:
#
# - Used in regression analysis to create a smooth line through a scatterplot.
#
# - Has a robust fitting method.  Because of this it can be used when there are noisy data values.
#
# - Non-parametric – no assumptions are made about the shape of the line of fit.
#
# <img src="img/lowess.jpg">

# %% [markdown]
# #### Code to run and plot lowess on AIS Staten Island sample (Pre-processed)

# %%
def calculate_lat_lon_in_spatialdf(spatialdf, shape_field='SHAPE', output_lat='latitude', output_lon='longitude'):

    def calculate_latitude(shape_field):
        return shape_field['y']

    def calculate_longitude(shape_field):
        return shape_field['x']

    # Calculate latitude and longitude fields from the shape attribute
    spatialdf[output_lat] = spatialdf.apply(lambda x: calculate_latitude(x[shape_field]), axis=1)
    spatialdf[output_lon] = spatialdf.apply(lambda x: calculate_longitude(x[shape_field]), axis=1)

    return spatialdf

# %%
ais_local_fgdb = r"D:\ANieto_SolutionEngineer\Data\DOT\BTS\Zone18_2014_07\Zone18_2014_07.gdb"
ais_sample_fc = "{0}//AIS_Sampler".format(ais_local_fgdb)
ais_sdf = calculate_lat_lon_in_spatialdf(arcgis.features.SpatialDataFrame.from_featureclass(ais_sample_fc))
ais_sdf
# Out:
#        OBJECTID   SOG    COG  Heading    ROT               BaseDateTime  \
# 0             1   0.0  292.0    243.0    0.0 2014-07-01 00:00:02.000000
# 1             2   0.0  292.0    243.0    0.0 2014-07-01 00:01:02.000000
# 2             3   0.0  292.0    243.0    0.0 2014-07-01 00:02:02.000000
# 3             4   0.0  292.0    243.0    0.0 2014-07-01 00:03:02.000000
# 4             5   0.0  292.0    244.0    0.0 2014-07-01 00:04:02.000000
# 5             6   0.0  292.0    244.0    0.0 2014-07-01 00:05:02.000000
# 6             7   0.0  292.0    244.0    0.0 2014-07-01 00:06:02.000000
# 7             8   0.0  292.0    245.0    0.0 2014-07-01 00:07:02.000000
# 8             9   0.0  292.0    245.0    0.0 2014-07-01 00:08:02.000000
# 9            10   0.0  292.0    245.0    0.0 2014-07-01 00:09:02.000000
# 10           11   0.0  292.0    245.0    0.0 2014-07-01 00:10:02.000000
# 11           12   0.0  292.0    245.0    0.0 2014-07-01 00:11:02.000000
# 12           13   0.1  205.0    245.0    0.0 2014-07-01 00:12:03.000000
# 13           14   0.0  204.0    245.0    0.0 2014-07-01 00:13:03.000000
# 14           15   0.1   67.0    244.0    0.0 2014-07-01 00:14:03.000001
# 15           16   0.1   67.0    244.0    0.0 2014-07-01 00:15:03.000000
# 16           17   0.1   72.0    245.0    0.0 2014-07-01 00:16:03.000000
# 17           18   0.1   68.0    245.0    0.0 2014-07-01 00:17:03.000001
# 18           19   0.1   71.0    245.0    0.0 2014-07-01 00:18:03.000000
# 19           20   0.0   77.0    244.0    0.0 2014-07-01 00:19:03.000000
# 20           21   0.0   77.0    245.0    0.0 2014-07-01 00:20:03.000000
# 21           22   0.0   77.0    244.0    0.0 2014-07-01 00:21:03.000000
# 22           23   0.0   77.0    244.0    0.0 2014-07-01 00:22:03.000000
# 23           24   0.0   77.0    244.0    0.0 2014-07-01 00:23:03.000000
# 24           25   0.0  157.0    244.0    0.0 2014-07-01 00:24:03.000000
# 25           26   0.0  161.0    245.0    0.0 2014-07-01 00:25:11.000000
# 26           27   0.0  161.0    245.0    0.0 2014-07-01 00:26:11.000000
# 27           28   0.0  243.0    245.0    0.0 2014-07-01 00:27:11.000001
# 28           29   0.0  243.0    245.0    0.0 2014-07-01 00:28:11.000000
# 29           30   0.0  243.0    245.0    0.0 2014-07-01 00:29:11.000000
# ...         ...   ...    ...      ...    ...                        ...
# 25154     25155  15.8  211.0     26.0    0.0 2014-07-31 23:30:04.000000
# 25155     25156  15.7  218.0     42.0    0.0 2014-07-31 23:31:04.000001
# 25156     25157  15.6  215.0     23.0  129.0 2014-07-31 23:32:04.000000
# 25157     25158  15.5  200.0     22.0    0.0 2014-07-31 23:33:04.000000
# 25158     25159  15.6  196.0     15.0    0.0 2014-07-31 23:34:04.000001
# 25159     25160  15.6  205.0     18.0    0.0 2014-07-31 23:35:04.000000
# 25160     25161  15.4  186.0     10.0  127.0 2014-07-31 23:36:04.000000
# 25161     25162  15.2  221.0     41.0    0.0 2014-07-31 23:37:04.000000
# 25162     25163  15.5  220.0    225.0  127.0 2014-07-31 23:38:04.000000
# 25163     25164  15.3  229.0    230.0    0.0 2014-07-31 23:39:04.000000
# 25164     25165  11.5  266.0    260.0  129.0 2014-07-31 23:40:04.000000
# 25165     25166   7.2  227.0    209.0  129.0 2014-07-31 23:41:04.000000
# 25166     25167   5.0  219.0    203.0    0.0 2014-07-31 23:42:04.000000
# 25167     25168   4.8  221.0    205.0    0.0 2014-07-31 23:43:04.000000
# 25168     25169   1.9  228.0     16.0    0.0 2014-07-31 23:44:04.000000
# 25169     25170   0.5  218.0    211.0    0.0 2014-07-31 23:45:07.000000
# 25170     25171   0.0  216.0     32.0    0.0 2014-07-31 23:46:10.000000
# 25171     25172   0.0  216.0     32.0    0.0 2014-07-31 23:47:10.000000
# 25172     25173   0.1  331.0     32.0    0.0 2014-07-31 23:48:10.000000
# 25173     25174   0.0  327.0     32.0    0.0 2014-07-31 23:49:10.000000
# 25174     25175   0.0  327.0     32.0    0.0 2014-07-31 23:50:10.000000
# 25175     25176   0.0  327.0     32.0    0.0 2014-07-31 23:51:10.000000
# 25176     25177   0.0  327.0     32.0    0.0 2014-07-31 23:52:10.000000
# 25177     25178   0.0  327.0     32.0    0.0 2014-07-31 23:53:10.000000
# 25178     25179   0.0  327.0     32.0    0.0 2014-07-31 23:54:10.000000
# 25179     25180   0.0  327.0     32.0    0.0 2014-07-31 23:55:10.000000
# 25180     25181   0.0  327.0     32.0    0.0 2014-07-31 23:56:10.000001
# 25181     25182   0.0  119.0     32.0    0.0 2014-07-31 23:57:10.000000
# 25182     25183   0.0  119.0     33.0    0.0 2014-07-31 23:58:10.000000
# 25183     25184   0.0  119.0     32.0    0.0 2014-07-31 23:59:10.000001
#
#        Status  VoyageID       MMSI ReceiverType  ReceiverID  \
# 0           0         7  367019000            b  2003669982
# 1           0         7  367019000            b  2003669982
# 2           0         7  367019000            b  2003669982
# 3           0         7  367019000            b  2003669982
# 4           0         7  367019000            b  2003669982
# 5           0         7  367019000            b  2003669982
# 6           0         7  367019000            b   003669984
# 7           0         7  367019000            b  2003669982
# 8           0         7  367019000            b  2003669982
# 9           0         7  367019000            b   003669984
# 10          0         7  367019000            b   003669983
# 11          0         7  367019000            b   003669983
# 12          0         7  367019000            b   003669983
# 13          0         7  367019000            b   003669984
# 14          0         7  367019000            b  2003669982
# 15          0         7  367019000            b   003669983
# 16          0         7  367019000            b  2003669982
# 17          0         7  367019000            b  2003669982
# 18          0         7  367019000            b   003669983
# 19          0         7  367019000            b   003669984
# 20          0         7  367019000            b   003669984
# 21          0         7  367019000            b   003669984
# 22          0         7  367019000            b   003669984
# 23          0         7  367019000            b   003669983
# 24          0         7  367019000            b  2003669982
# 25          0         7  367019000            b   003669983
# 26          0         7  367019000            b  2003669982
# 27          0         7  367019000            b   003669983
# 28          0         7  367019000            b   003669984
# 29          0         7  367019000            b   003669984
# ...       ...       ...        ...          ...         ...
# 25154       0     19525  367019000            b   003669983
# 25155       0     19525  367019000            b   003669983
# 25156       0     19525  367019000            b   003669984
# 25157       0     19525  367019000            b   003669983
# 25158       0     19525  367019000            b   003669984
# 25159       0     19525  367019000            b   003669983
# 25160       0     19525  367019000            b   003669984
# 25161       0     19525  367019000            b   003669983
# 25162       0     19525  367019000            b  2003669982
# 25163       0     19525  367019000            b   003669984
# 25164       0     19525  367019000            b   003669983
# 25165       0     19525  367019000            b   003669984
# 25166       0     19525  367019000            b   003669984
# 25167       0     19525  367019000            b  2003669982
# 25168       0     19525  367019000            b   003669984
# 25169       0     19525  367019000            b   003669984
# 25170       0     19525  367019000            b   003669984
# 25171       0     19525  367019000            b   003669983
# 25172       0     19525  367019000            b  2003669982
# 25173       0     19525  367019000            b   003669984
# 25174       0     19525  367019000            b   003669983
# 25175       0     19525  367019000            b  2003669982
# 25176       0     19525  367019000            b  2003669982
# 25177       0     19525  367019000            b   003669984
# 25178       0     19525  367019000            b  2003669982
# 25179       0     19525  367019000            b   003669983
# 25180       0     19525  367019000            b   003669983
# 25181       0     19525  367019000            b   003669983
# 25182       0     19525  367019000            b   003669984
# 25183       0     19525  367019000            b   003669984
#
#                                                    SHAPE   latitude  longitude
# 0      {'x': -74.071757, 'y': 40.64426499999999, 'spa...  40.644265 -74.071757
# 1      {'x': -74.071813, 'y': 40.64412200000001, 'spa...  40.644122 -74.071813
# 2      {'x': -74.071802, 'y': 40.64416299999999, 'spa...  40.644163 -74.071802
# 3      {'x': -74.071812, 'y': 40.64414199999999, 'spa...  40.644142 -74.071812
# 4      {'x': -74.071825, 'y': 40.644149999999996, 'sp...  40.644150 -74.071825
# 5      {'x': -74.07182, 'y': 40.644135000000006, 'spa...  40.644135 -74.071820
# 6      {'x': -74.071818, 'y': 40.64414199999999, 'spa...  40.644142 -74.071818
# 7      {'x': -74.071817, 'y': 40.64410000000001, 'spa...  40.644100 -74.071817
# 8      {'x': -74.071768, 'y': 40.644115, 'spatialRefe...  40.644115 -74.071768
# 9      {'x': -74.071723, 'y': 40.64408800000001, 'spa...  40.644088 -74.071723
# 10     {'x': -74.071805, 'y': 40.64409699999999, 'spa...  40.644097 -74.071805
# 11     {'x': -74.071867, 'y': 40.644071999999994, 'sp...  40.644072 -74.071867
# 12     {'x': -74.071893, 'y': 40.644059999999996, 'sp...  40.644060 -74.071893
# 13     {'x': -74.07189, 'y': 40.644053000000014, 'spa...  40.644053 -74.071890
# 14     {'x': -74.07182, 'y': 40.644059999999996, 'spa...  40.644060 -74.071820
# 15     {'x': -74.071825, 'y': 40.64407, 'spatialRefer...  40.644070 -74.071825
# 16     {'x': -74.071783, 'y': 40.644048, 'spatialRefe...  40.644048 -74.071783
# 17     {'x': -74.071763, 'y': 40.644053000000014, 'sp...  40.644053 -74.071763
# 18     {'x': -74.071783, 'y': 40.64408800000001, 'spa...  40.644088 -74.071783
# 19     {'x': -74.071778, 'y': 40.64408499999999, 'spa...  40.644085 -74.071778
# 20     {'x': -74.071858, 'y': 40.64403200000001, 'spa...  40.644032 -74.071858
# 21     {'x': -74.07185, 'y': 40.64402799999999, 'spat...  40.644028 -74.071850
# 22     {'x': -74.071762, 'y': 40.64407499999999, 'spa...  40.644075 -74.071762
# 23     {'x': -74.071787, 'y': 40.64408, 'spatialRefer...  40.644080 -74.071787
# 24     {'x': -74.07174, 'y': 40.644058, 'spatialRefer...  40.644058 -74.071740
# 25     {'x': -74.07174, 'y': 40.644082, 'spatialRefer...  40.644082 -74.071740
# 26     {'x': -74.07179, 'y': 40.644115, 'spatialRefer...  40.644115 -74.071790
# 27     {'x': -74.07179, 'y': 40.64411999999999, 'spat...  40.644120 -74.071790
# 28     {'x': -74.071822, 'y': 40.64410000000001, 'spa...  40.644100 -74.071822
# 29     {'x': -74.071842, 'y': 40.64409499999999, 'spa...  40.644095 -74.071842
# ...                                                  ...        ...        ...
# 25154  {'x': -74.037193, 'y': 40.683188, 'spatialRefe...  40.683188 -74.037193
# 25155  {'x': -74.040345, 'y': 40.67943299999999, 'spa...  40.679433 -74.040345
# 25156  {'x': -74.044002, 'y': 40.67618999999999, 'spa...  40.676190 -74.044002
# 25157  {'x': -74.046072, 'y': 40.67219800000001, 'spa...  40.672198 -74.046072
# 25158  {'x': -74.048092, 'y': 40.668182, 'spatialRefe...  40.668182 -74.048092
# 25159  {'x': -74.050247, 'y': 40.66416000000001, 'spa...  40.664160 -74.050247
# 25160  {'x': -74.051412, 'y': 40.65987799999999, 'spa...  40.659878 -74.051412
# 25161  {'x': -74.05405, 'y': 40.65635800000001, 'spat...  40.656358 -74.054050
# 25162  {'x': -74.057965, 'y': 40.65254999999999, 'spa...  40.652550 -74.057965
# 25163  {'x': -74.062207, 'y': 40.64976200000001, 'spa...  40.649762 -74.062207
# 25164  {'x': -74.066682, 'y': 40.64894799999999, 'spa...  40.648948 -74.066682
# 25165  {'x': -74.069417, 'y': 40.64787000000001, 'spa...  40.647870 -74.069417
# 25166  {'x': -74.070688, 'y': 40.64671000000001, 'spa...  40.646710 -74.070688
# 25167  {'x': -74.071815, 'y': 40.64565300000001, 'spa...  40.645653 -74.071815
# 25168  {'x': -74.07236, 'y': 40.64551800000001, 'spat...  40.645518 -74.072360
# 25169  {'x': -74.072662, 'y': 40.64483200000001, 'spa...  40.644832 -74.072662
# 25170  {'x': -74.072335, 'y': 40.64531199999999, 'spa...  40.645312 -74.072335
# 25171  {'x': -74.072308, 'y': 40.645285, 'spatialRefe...  40.645285 -74.072308
# 25172  {'x': -74.072337, 'y': 40.64535699999999, 'spa...  40.645357 -74.072337
# 25173  {'x': -74.072337, 'y': 40.645377999999994, 'sp...  40.645378 -74.072337
# 25174  {'x': -74.07237, 'y': 40.64535699999999, 'spat...  40.645357 -74.072370
# 25175  {'x': -74.072332, 'y': 40.645398, 'spatialRefe...  40.645398 -74.072332
# 25176  {'x': -74.072297, 'y': 40.645408, 'spatialRefe...  40.645408 -74.072297
# 25177  {'x': -74.072303, 'y': 40.645388, 'spatialRefe...  40.645388 -74.072303
# 25178  {'x': -74.07235, 'y': 40.645317000000006, 'spa...  40.645317 -74.072350
# 25179  {'x': -74.072312, 'y': 40.64533499999999, 'spa...  40.645335 -74.072312
# 25180  {'x': -74.072383, 'y': 40.645309999999995, 'sp...  40.645310 -74.072383
# 25181  {'x': -74.072318, 'y': 40.645263, 'spatialRefe...  40.645263 -74.072318
# 25182  {'x': -74.07233, 'y': 40.64532, 'spatialRefere...  40.645320 -74.072330
# 25183  {'x': -74.072322, 'y': 40.645325000000014, 'sp...  40.645325 -74.072322
#
# [25184 rows x 14 columns]

# %% [markdown]
# ### Plot of First Run of Lowess

# %%
plotly.offline.plot({
    "data": [plotly.graph_objs.Scatter(x=ais_sdf['longitude'], y=ais_sdf['latitude'])]
})
# Out:
# 'file://C:\\Users\\albe9057\\Documents\\GitHub\\AISFerryRouteDigitization_Prototype\\scripts\\prototype\\temp-plot.html'

# %% [markdown]
# <img src="img/newplot.png">

# %% [markdown]
# ##### Run lowess using Staten Island AIS sample (Pre-processed)

# %%
lowess = sm.nonparametric.lowess
lowess_ais = lowess(ais_sdf['latitude'], ais_sdf['longitude'])

# %% [markdown]
# #### Plot Lowess first run

# %%
plotly.offline.plot({
    "data": [plotly.graph_objs.Scatter(x=lowess_ais[:,0], y=lowess_ais[:,1])]
})

# %% [markdown]
# <img src="img/newplot1.png">

# %% [markdown]
# #### Pre-QC Route Layer on WebMap

# %%
preqc_route_layer = gis.content.search("AIS_SIFerryRoute_PreQC", item_type="feature service")[0]
preqc_route_layer

# %%
preqc_route_map = gis.map("New York City")
# preqc_route_map.basemap = 'ocean'
# preqc_route_map.add_layer(preqc_route_layer)
preqc_route_map

# %%
preqc_route_map.basemap = 'gray'

# %%
preqc_route_map.add_layer(ais_sample)

# %%
preqc_route_map.add_layer(preqc_route_layer)

# %% [markdown]
# <img src="img/capture01.PNG">

# %% [markdown]
# #### The north end of the route overshoots the terminal... let's fix this.

# %% [markdown]
# # Part 3: Run QC - Density-based Clustering

# %% [markdown]
# #### Explanation of Density-based Clustering

# %% [markdown]
# http://pro.arcgis.com/en/pro-app/tool-reference/spatial-statistics/how-density-based-clustering-works.htm

# %% [markdown]
# <img src="img/capture02.PNG">

# %% [markdown]
# <img src="img/capture03.PNG">

# %% [markdown]
# #### Code to Retrieve Density-based Clustering Layers (with noise, and without noise) and Show on Maps

# %% [markdown]
# DBSCAN With noise

# %%
dbcluster_lyr_full = gis.content.search("OPTICS_AIS_Sampler_50ft_lowsens")[0]
dbcluster_map = gis.map("New York City")
dbcluster_map.basemap = "gray"
dbcluster_map.add_layer(dbcluster_lyr_full)
dbcluster_map

# %% [markdown]
# <img src="img/capture04.PNG">

# %% [markdown]
# Without noise

# %%
dbcluster_lyr_full_nonoise = gis.content.search("OPTICS_AIS_Sampler_50ft_lowsens_FILTER_nonnoise")[0]
dbcluster_map = gis.map("New York City")
dbcluster_map.basemap = "gray"
dbcluster_map.add_layer(dbcluster_lyr_full_nonoise)
dbcluster_map

# %% [markdown]
# <img src="img/capture.png">

# %% [markdown]
# # Part 4: Post QC - Map

# %% [markdown]
# #### Lowess Layer on WebMap

# %%
postqc_route_layer = gis.content.search("AIS_SIFerryRoute_PostQC")[0]
postqc_route_layer

# %%
postqc_route_map = gis.map("Staten Island")
# preqc_route_map.basemap = 'ocean'
# preqc_route_map.add_layer(preqc_route_layer)
postqc_route_map

# %%
postqc_route_map.basemap = 'gray'

# %%
postqc_route_map.add_layer(postqc_route_layer)

# %% [markdown]
# <img src="img/capture06.png">

# %% [markdown]
# ### Next Steps

# %% [markdown]
# - Continued improvement on generalization function.
# - Iteratation on multiple routes.
# - Output lowess line into geospatial web application.
# - Published authoritative records into <a ref="https://osav-usdot.opendata.arcgis.com/">Bureau of Transportation Open Data site.</a>
